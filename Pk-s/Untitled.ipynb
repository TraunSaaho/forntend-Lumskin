# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Abhishek\Downloads\lumniskin\lumni_skin_products_full.csv")

# %%
df
# Out:
#     product_id          product_name         brand         ingredient  \
# 0          101    Salicylic Cleanser    Minimalist     Salicylic Acid
# 1          102      Acne Control Gel  The Derma Co   Benzoyl Peroxide
# 2          103    Adapalene 0.1% Gel      Galderma          Adapalene
# 3          104        Oil Free Serum          Plum        Niacinamide
# 4          105     Acne Repair Cream           1Rx       Azelaic Acid
# ..         ...                   ...           ...                ...
# 75         806         Peptide Serum    Minimalist           Peptides
# 76         807     Antioxidant Serum    Minimalist  Antioxidant Serum
# 77         808     Niacinamide Serum       Pilgrim        Niacinamide
# 78         809         Barrier Cream       Reequil     Ceramide Cream
# 79         810  Brightening Cleanser    Minimalist      Mild Cleanser
#
#    condition severity_level skin_type product_type  price  rating  \
# ...

# %%
df.to_json("products.json", orient="records", indent=4)

print("CSV converted to JSON successfully")
# Out:
# CSV converted to JSON successfully
